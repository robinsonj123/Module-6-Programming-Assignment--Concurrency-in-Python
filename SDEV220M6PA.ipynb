# %% [markdown]
# # 13.1 Write the current date as a string to the text file today.txt.

# %%
from datetime import date
today = date.today()
with open("today.txt", "w") as file: 
    file.write(str(today))

# %% [markdown]
# # 13.2 Read the text file today.txt into the string today_string

# %%
with open("today.txt", "r") as file:
    today_string = file.read()

today_string
# Out:
# '2025-12-06'

# %% [markdown]
# # 13.3 Parse the date from today_string.

# %%
from datetime import datetime

with open("today.txt", "r") as file:
    today_string = file.read().strip()

parsed_date = datetime.strptime(today_string, "%Y-%m-%d")

parsed_date
# Out:
# datetime.datetime(2025, 12, 6, 0, 0)

# %% [markdown]
# # 15.1 Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between zero and one, print the current time, and then exit.

# %%
from multiprocessing.dummy import Pool
import time, random
from datetime import datetime

def worker(_):
    time.sleep(random.random())
    print("Process time:", datetime.now())

pool = Pool(3)

pool.map(worker, range(3))

pool.close()
pool.join()
# Out:
# Process time: 2025-12-06 21:39:28.588068
# Process time: 2025-12-06 21:39:28.906803
# Process time: 2025-12-06 21:39:29.106632
